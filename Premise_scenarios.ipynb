# %% [markdown]
# # Tutorial: use of premise

# %%
#import packages
from premise import *
import bw2data
#from datapackage import Package
from premise import NewDatabase
import brightway2 as bw

# %%
list(bw.projects)
# Out:
# [Project: Electricity_DE,
#  Project: bw2_seminar_2017,
#  Project: bw2_tutorial,
#  Project: Alicia,
#  Project: default,
#  Project: superstructure,
#  Project: prueba BW,
#  Project: Run_test,
#  Project: AB_workshop,
#  Project: Biogas_model,
#  Project: Biogas_12_OCT,
#  Project: brightcon22,
#  Project: OWE,
#  Project: Electricity_markets,
#  Project: premise,
#  Project: Correlated and dependent sampling]

# %%
# %pwd
# Out:
# 'D:\\Benitez\\BW25_A_school'

# %%
bw.projects.set_current("premise")

# %%
bw2data.databases
# Out:
# Databases dictionary with 5 object(s):
# 	Image_RCPs_eco_3.8
# 	OWE
# 	biosphere3
# 	ecoinvent 3.8 cutoff
# 	test_sp

# %%
#For new projects, first we need to set up
#bw.bw2setup()  #this command install the biosphere (elementary flows and LCIA)

# %%
bw2data.databases
# Out:
# Databases dictionary with 5 object(s):
# 	Image_RCPs_eco_3.8
# 	OWE
# 	biosphere3
# 	ecoinvent 3.8 cutoff
# 	test_sp

# %%
#fpei38 = r'C:\Ecoinvent\3.8\ecoinvent 3.8_cutoff_ecoSpold02\datasets'

# %%
#if 'ecoinvent 3.8 cutoff' in bw.databases:
#  print("Database has already been imported")
#else:
#    ei38 = bw.SingleOutputEcospold2Importer(fpei38, 'ecoinvent 3.8 cutoff')
#   ei38.apply_strategies()
#    ei38.statistics()
#    ei38.write_database()
# Out:
# Database has already been imported

# %%
#databases installed in the current project
bw2data.databases
# Out:
# Databases dictionary with 5 object(s):
# 	Image_RCPs_eco_3.8
# 	OWE
# 	biosphere3
# 	ecoinvent 3.8 cutoff
# 	test_sp

# %%
clear_cache()
# Out:
# Cache folder cleared!

# %%
ndb = NewDatabase(
            scenarios=[
                {"model":"image", "pathway":"SSP2-RCP19", "year":2020},
                {"model":"image", "pathway":"SSP2-RCP19", "year":2025},
                {"model":"image", "pathway":"SSP2-RCP19", "year":2030},
                {"model":"image", "pathway":"SSP2-RCP19", "year":2035},
                {"model":"image", "pathway":"SSP2-RCP19", "year":2040},
                {"model":"image", "pathway":"SSP2-RCP19", "year":2045},
                {"model":"image", "pathway":"SSP2-RCP19", "year":2050},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2020},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2025},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2030},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2035},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2040},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2045},
                {"model":"image", "pathway":"SSP2-RCP26", "year":2050},
                {"model":"image", "pathway":"SSP2-Base", "year":2020},
                {"model":"image", "pathway":"SSP2-Base", "year":2025},
                {"model":"image", "pathway":"SSP2-Base", "year":2030},
                {"model":"image", "pathway":"SSP2-Base", "year":2035},
                {"model":"image", "pathway":"SSP2-Base", "year":2040},
                {"model":"image", "pathway":"SSP2-Base", "year":2045},
                {"model":"image", "pathway":"SSP2-Base", "year":2050},
            ],
            source_db="ecoinvent 3.8 cutoff", # <-- name of the database in the BW2 project. Must be a string.
            source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
            #additional_inventories=[
              #  {"filepath": r'D:\Benitez\Premise\lci-batteries.xlsx', "ecoinvent version": "3.8"}, # <-- this is NEW
               # {"filepath": r'D:\Benitez\Premise\lci-PV.xlsx', "ecoinvent version": "3.8"}, # <-- this is NEW
           # ]
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
            )
# Out:
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
#
# ...

# %%
ndb = NewDatabase(
            scenarios=[
                {"model":"remind", "pathway":"SSP2-Base", "year":2020},
                {"model":"remind", "pathway":"SSP2-Base", "year":2030},
                {"model":"remind", "pathway":"SSP2-Base", "year":2040},
                {"model":"remind", "pathway":"SSP2-Base", "year":2050},
                
                {"model":"remind", "pathway":"SSP2-PkBudg1100", "year":2020},
                {"model":"remind", "pathway":"SSP2-PkBudg1100", "year":2030},
                {"model":"remind", "pathway":"SSP2-PkBudg1100", "year":2040},
                {"model":"remind", "pathway":"SSP2-PkBudg1100", "year":2050},
                
                {"model":"remind", "pathway":"SSP2-PkBudg900", "year":2020},
                {"model":"remind", "pathway":"SSP2-PkBudg900", "year":2030},
                {"model":"remind", "pathway":"SSP2-PkBudg900", "year":2040},
                {"model":"remind", "pathway":"SSP2-PkBudg900", "year":2050},
            ],
            source_db="ecoinvent 3.8 cutoff", # <-- name of the database in the BW2 project. Must be a string.
            source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
            #additional_inventories=[
              #  {"filepath": r'D:\Benitez\Premise\lci-batteries.xlsx', "ecoinvent version": "3.8"}, # <-- this is NEW
               # {"filepath": r'D:\Benitez\Premise\lci-PV.xlsx', "ecoinvent version": "3.8"}, # <-- this is NEW
           # ]
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
            )
# Out:
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
#
# ...

# %%
for act in ndb.scenarios[0]['database']:
    if "electricity" in act["name"]:
        for exc in act['exchanges']:
            print(exc['name'], exc['amount'], exc.get('location'))

# %%
ndb.update_electricity()
# Out:
# /////////////////////////// ELECTRICITY ////////////////////////////
# Update natural gas extraction datasets.
# Update efficiency of solar PV.
# Log of changes in photovoltaics efficiencies saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Create biomass markets.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Log of deleted electricity markets saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Log of created electricity markets saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Done!
# Adjust efficiency of power plants...
# Log of changes in power plants efficiencies saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal CHP CCS
# ...

# %%
ndb.write_superstructure_db_to_brightway(filepath=r'D:\Benitez\AB_results\My superestrucutre', name="remind_eco_3.8")
# Out:
# Prepare database 1.
# Prepare database 2.
# Prepare database 3.
# Prepare database 4.
# Prepare database 5.
# Prepare database 6.
# Prepare database 7.
# Prepare database 8.
# Prepare database 9.
# Prepare database 10.
# Prepare database 11.
# Prepare database 12.
# Prepare database 13.
# Prepare database 14.
# Prepare database 15.
# Prepare database 16.
# Prepare database 17.
# Prepare database 18.
# Prepare database 19.
# Prepare database 20.
# Prepare database 21.
# Looping through scenarios to detect changes...
# Export a scenario difference file.
# Dropped 540 duplicates.
# Scenario difference file exported to D:\Benitez\AB_results\My superestrucutre\scenario_diff_Image_RCPs_eco_3.8.xlsx!
# Adding exchanges to 7635 activities.
# Adding 3807 extra activities to the original database...
# Done!
# One or multiple duplicates detected. Removing them...
# 24029 datasets
# 729336 exchanges
# 0 unlinked exchanges
# Writing activities to SQLite3 database:
# ...

# %%
# %pwd
# Out:
# 'D:\\'

# %%
bw.projects.dir
# Out:
# 'C:\\Users\\Benitez\\AppData\\Local\\pylca\\Brightway3\\premise.d4cc582681190826279977734a65c677'

# %%
import bw2io as bi

# %%
bi.BW2Package.export_obj(bw.Database("remind_eco_3.8"), filename="remind_eco_3.8", folder=".")
# Out:
# 'C:\\Users\\Benitez\\AppData\\Local\\pylca\\Brightway3\\premise.d4cc582681190826279977734a65c677\\.\\Image_RCPs_eco_38.84c181f0c82ad0650288aa2f1974141a.bw2package'

# %%
ndb = NewDatabase(
            scenarios=[
                {"model":"image", "pathway":"SSP2-RCP19", "year":2020},
                ],
            source_db="ecoinvent 3.8 cutoff", # <-- name of the database in the BW2 project. Must be a string.
            source_version="3.8", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
            #additional_inventories=[
              #  {"filepath": r'D:\Benitez\Premise\lci-batteries.xlsx', "ecoinvent version": "3.8"}, # <-- this is NEW
               # {"filepath": r'D:\Benitez\Premise\lci-PV.xlsx', "ecoinvent version": "3.8"}, # <-- this is NEW
           # ]
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
            )
# Out:
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
#
# ...

# %%
ndb.update_electricity()
# Out:
# /////////////////////////// ELECTRICITY ////////////////////////////
# Update natural gas extraction datasets.
# Update efficiency of solar PV.
# Log of changes in photovoltaics efficiencies saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Create biomass markets.
# Empty old electricity datasets
# Create high voltage markets.
# Create medium voltage markets.
# Create low voltage markets.
# Log of deleted electricity markets saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Log of created electricity markets saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Done!
# Adjust efficiency of power plants...
# Log of changes in power plants efficiencies saved in C:\bw2-python\envs\prem\Lib\site-packages\premise\data/logs
# Rescale inventories and emissions for Oil CC CCS
# Rescale inventories and emissions for Gas CHP CCS
# Rescale inventories and emissions for Coal PC
# Rescale inventories and emissions for Coal CHP CCS
# ...

# %%
ndb.write_superstructure_db_to_brightway(filepath=r'D:\Benitez\AB_results\My superestrucutre', name="test_remind_eco_3.8")
# Out:
# Prepare database 1.
# One or multiple duplicates detected. Removing them...
# Looping through scenarios to detect changes...
# Export a scenario difference file.
# Dropped 0 duplicates.
# Scenario difference file exported to D:\Benitez\AB_results\My superestrucutre\scenario_diff_test_sp.xlsx!
# Adding exchanges to 7589 activities.
# Adding 3267 extra activities to the original database...
# Done!
# 24029 datasets
# 689622 exchanges
# 0 unlinked exchanges
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:01:39
# Title: Writing activities to SQLite3 database:
#   Started: 11/09/2022 15:53:37
#   Finished: 11/09/2022 15:55:16
#   Total time elapsed: 00:01:39
#   CPU %: 63.80
#   Memory %: 28.43
# Created database: test_sp
